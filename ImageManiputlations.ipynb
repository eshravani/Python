# %% [markdown]
# <a href="https://colab.research.google.com/github/eshravani/Python/blob/python_branch/ImageManiputlations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# !gdown 1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# To: /content/emma_stone.jpeg
# 100% 80.3k/80.3k [00:00<00:00, 3.04MB/s]

# %%
img = plt.imread("emma_stone.jpeg")
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
print(img.ndim)
# Out:
# 3

# %%
print(img.shape)
img
# Out:
# (600, 900, 3)
# array([[[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 64,  36,  12],
#         [ 62,  34,  10],
#         [ 61,  33,   9]],
#
#        [[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 62,  34,  10],
#         [ 61,  33,   9],
#         [ 60,  32,   8]],
#
#        [[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 61,  33,   9],
#         [ 61,  33,   9],
#         [ 60,  32,   8]],
#
#        ...,
#
#        [[174, 196, 207],
#         [174, 196, 207],
#         [174, 196, 207],
#         ...,
#         [ 75,  43,  22],
#         [ 74,  42,  21],
#         [ 73,  41,  20]],
#
#        [[174, 196, 207],
#         [174, 196, 207],
#         [174, 196, 207],
#         ...,
#         [ 75,  43,  22],
#         [ 74,  42,  21],
#         [ 73,  41,  20]],
#
#        [[174, 196, 207],
#         [174, 196, 207],
# ...

# %%
import numpy as np

# %%
np.transpose(img,(0,1,2))
# Out:
# array([[[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 64,  36,  12],
#         [ 62,  34,  10],
#         [ 61,  33,   9]],
#
#        [[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 62,  34,  10],
#         [ 61,  33,   9],
#         [ 60,  32,   8]],
#
#        [[145, 194, 235],
#         [145, 194, 235],
#         [144, 193, 234],
#         ...,
#         [ 61,  33,   9],
#         [ 61,  33,   9],
#         [ 60,  32,   8]],
#
#        ...,
#
#        [[174, 196, 207],
#         [174, 196, 207],
#         [174, 196, 207],
#         ...,
#         [ 75,  43,  22],
#         [ 74,  42,  21],
#         [ 73,  41,  20]],
#
#        [[174, 196, 207],
#         [174, 196, 207],
#         [174, 196, 207],
#         ...,
#         [ 75,  43,  22],
#         [ 74,  42,  21],
#         [ 73,  41,  20]],
#
#        [[174, 196, 207],
#         [174, 196, 207],
#         [174, 196, 207],
# ...

# %%
invertedimg = np.transpose(img,(1,0,2))
print(invertedimg.shape)
# Out:
# (900, 600, 3)

# %%
plt.imshow(invertedimg)

# %%
#CROP IMAGE to get only face
plt.imshow(img)

# %%
cropped_img = img[:400,250:650,:]
plt.imshow(cropped_img)
